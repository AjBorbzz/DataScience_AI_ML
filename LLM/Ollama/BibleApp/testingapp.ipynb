# %%
import pandas as pd
from pathlib import Path
import json

# %%
data_path = Path("data/asv.json")
print(data_path
      )
# Out:
# data/asv.json

# %%
with open(data_path) as f:
    data = json.load(f)

# Flatten the data
df = pd.json_normalize(data)

# %%
df = df["verses"]
df
# Out:
# 0    [{'book_name': 'Genesis', 'book': 1, 'chapter'...
# Name: verses, dtype: object

# %%
df = pd.json_normalize(df)
df
# Out:
#                                                0      \
# 0  {'book_name': 'Genesis', 'book': 1, 'chapter':...
#
#                                                1      \
# 0  {'book_name': 'Genesis', 'book': 1, 'chapter':...
#
#                                                2      \
# 0  {'book_name': 'Genesis', 'book': 1, 'chapter':...
#
#                                                3      \
# 0  {'book_name': 'Genesis', 'book': 1, 'chapter':...
#
#                                                4      \
# 0  {'book_name': 'Genesis', 'book': 1, 'chapter':...
#
#                                                5      \
# 0  {'book_name': 'Genesis', 'book': 1, 'chapter':...
#
#                                                6      \
# 0  {'book_name': 'Genesis', 'book': 1, 'chapter':...
#
#                                                7      \
# 0  {'book_name': 'Genesis', 'book': 1, 'chapter':...
#
#                                                8      \
# ...

# %%
df[0]
# Out:
# 0    {'book_name': 'Genesis', 'book': 1, 'chapter':...
# Name: 0, dtype: object
